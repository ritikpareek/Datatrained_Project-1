# %% [markdown]
# # Mushroom Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
ds=pd.read_csv('mushroom.csv')

# %%
df=pd.DataFrame(ds)

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
df.shape
# Out:
# (8124, 23)

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
for column in df.columns:
    df[column] = labelencoder.fit_transform(df[column])

# %%
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %%
df.describe()
# Out:
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.482029     3.348104     1.827671     4.504677     0.415559
# std       0.499708     1.604329     1.229873     2.545821     0.492848
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  8124.000000      8124.000000   8124.000000  8124.000000  8124.000000
# mean      4.144756         0.974151      0.161497     0.309207     4.810684
# std       2.103729         0.158695      0.368011     0.462195     3.540359
# ...

# %%
sns.boxplot(df['cap-shape'],df['cap-color'])

# %%
sns.scatterplot(df['cap-color'],df['class'])

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.052951     0.178446  -0.031384
# cap-shape                 0.052951   1.000000    -0.050454  -0.048203
# cap-surface               0.178446  -0.050454     1.000000  -0.019402
# cap-color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment           0.129200   0.078865    -0.034180   0.041436
# gill-spacing             -0.348387   0.013196    -0.282306   0.144259
# gill-size                 0.540024   0.054050     0.208100  -0.169464
# gill-color               -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk-root               -0.379361   0.030191    -0.126245   0.321274
# ...

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True)

# %%
x=df.iloc[:,1:]
y=df.iloc[:,0]
print(x.shape)
y=y.values.reshape(y.shape[0],1)
print(y.shape)
# Out:
# (8124, 22)
# (8124, 1)

# %%
df['class'].value_counts()
# Out:
# 0    4208
# 1    3916
# Name: class, dtype: int64

# %%
x
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0             5            2          4        1     6                1
# 1             5            2          9        1     0                1
# 2             0            2          8        1     3                1
# 3             5            3          8        1     6                1
# 4             5            2          3        0     5                1
# ...         ...          ...        ...      ...   ...              ...
# 8119          3            2          4        0     5                0
# 8120          5            2          4        0     5                0
# 8121          2            2          4        0     5                0
# 8122          3            3          4        0     8                1
# 8123          5            2          4        0     5                0
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# ...

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
max_score=0
for r in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=r)
    lg=LogisticRegression()
    lg.fit(x_train,y_train)
    pred=lg.predict(x_test)
    acc=accuracy_score(y_test,pred)
    print('accuracy score of at',r,'is',acc)
    if acc>max_score:
        max_score=acc
        random_state=r
        
print('\n')
print(max_score)
print(random_state)
# Out:
# accuracy score of at 42 is 0.9499589827727646
# accuracy score of at 43 is 0.9462674323215751
# accuracy score of at 44 is 0.9552912223133716
# accuracy score of at 45 is 0.9470877768662839
# accuracy score of at 46 is 0.9491386382280558
# accuracy score of at 47 is 0.948318293683347
# accuracy score of at 48 is 0.9507793273174734
# accuracy score of at 49 is 0.9487284659557014
# accuracy score of at 50 is 0.9474979491386383
# accuracy score of at 51 is 0.9491386382280558
# accuracy score of at 52 is 0.9454470877768663
# accuracy score of at 53 is 0.9548810500410172
# accuracy score of at 54 is 0.9565217391304348
# accuracy score of at 55 is 0.9528301886792453
# accuracy score of at 56 is 0.948318293683347
# accuracy score of at 57 is 0.9438063986874488
# accuracy score of at 58 is 0.9470877768662839
# accuracy score of at 59 is 0.9405250205086136
# accuracy score of at 60 is 0.9462674323215751
# accuracy score of at 61 is 0.955701394585726
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=94)
lg=LogisticRegression()
lg.fit(x_train,y_train)
pred=lg.predict(x_test)

# %%
accuracy_score(y_test,pred)
# Out:
# 0.9569319114027892

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[1189,   52],
#        [  53, 1144]], dtype=int64)

# %%
classification_report(y_test,pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.96      0.96      0.96      1241\n           1       0.96      0.96      0.96      1197\n\n    accuracy                           0.96      2438\n   macro avg       0.96      0.96      0.96      2438\nweighted avg       0.96      0.96      0.96      2438\n'

# %% [markdown]
# # Kneighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
max_score=0
for r in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=r)
    kn=KNeighborsClassifier()
    kn.fit(x_train,y_train)
    pred=kn.predict(x_test)
    acc=accuracy_score(y_test,pred)
    print('accuracy score of at',r,'is',acc)
    if acc>max_score:
        max_score=acc
        random_state=r
        
print('\n')
print(max_score)
print(random_state)
# Out:
# accuracy score of at 42 is 0.9954881050041017
# accuracy score of at 43 is 0.9995898277276456
# accuracy score of at 44 is 0.9987694831829368
# accuracy score of at 45 is 0.9979491386382281
# accuracy score of at 46 is 0.9987694831829368
# accuracy score of at 47 is 0.9991796554552912
# accuracy score of at 48 is 0.9983593109105825
# accuracy score of at 49 is 0.9958982772764561
# accuracy score of at 50 is 0.9971287940935193
# accuracy score of at 51 is 1.0
# accuracy score of at 52 is 0.9983593109105825
# accuracy score of at 53 is 0.9979491386382281
# accuracy score of at 54 is 1.0
# accuracy score of at 55 is 0.9991796554552912
# accuracy score of at 56 is 0.9987694831829368
# accuracy score of at 57 is 0.9979491386382281
# accuracy score of at 58 is 0.9971287940935193
# accuracy score of at 59 is 0.9983593109105825
# accuracy score of at 60 is 0.9987694831829368
# accuracy score of at 61 is 0.9991796554552912
# accuracy score of at 62 is 0.9987694831829368
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=51)
kn=KNeighborsClassifier()
kn.fit(x_train,y_train)
pred=kn.predict(x_test)

# %%
accuracy_score(y_test,pred)
# Out:
# 1.0

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[1306,    0],
#        [   0, 1132]], dtype=int64)

# %%
classification_report(y_test,pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00      1306\n           1       1.00      1.00      1.00      1132\n\n    accuracy                           1.00      2438\n   macro avg       1.00      1.00      1.00      2438\nweighted avg       1.00      1.00      1.00      2438\n'

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC

# %%
max_score=0
for r in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=r)
    svc=SVC()
    svc.fit(x_train,y_train)
    pred=svc.predict(x_test)
    acc=accuracy_score(y_test,pred)
    print('accuracy score of at',r,'is',acc)
    if acc>max_score:
        max_score=acc
        random_state=r
        
print('\n')
print(max_score)
print(random_state)
# Out:
# accuracy score of at 42 is 0.9893355209187858
# accuracy score of at 43 is 0.9848236259228876
# accuracy score of at 44 is 0.9897456931911403
# accuracy score of at 45 is 0.9909762100082035
# accuracy score of at 46 is 0.9913863822805579
# accuracy score of at 47 is 0.9893355209187858
# accuracy score of at 48 is 0.9872846595570139
# accuracy score of at 49 is 0.9840032813781788
# accuracy score of at 50 is 0.9856439704675964
# accuracy score of at 51 is 0.9893355209187858
# accuracy score of at 52 is 0.9881050041017228
# accuracy score of at 53 is 0.9876948318293683
# accuracy score of at 54 is 0.9909762100082035
# accuracy score of at 55 is 0.9905660377358491
# accuracy score of at 56 is 0.9860541427399507
# accuracy score of at 57 is 0.9835931091058244
# accuracy score of at 58 is 0.9905660377358491
# accuracy score of at 59 is 0.9860541427399507
# accuracy score of at 60 is 0.9913863822805579
# accuracy score of at 61 is 0.9893355209187858
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=82)
svc=SVC()
svc.fit(x_train,y_train)
pred=svc.predict(x_test)

# %%
accuracy_score(y_test,pred)
# Out:
# 0.994667760459393

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[1267,    0],
#        [  13, 1158]], dtype=int64)

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
max_score=0
for r in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=r)
    dtc=DecisionTreeClassifier()
    dtc.fit(x_train,y_train)
    pred=dtc.predict(x_test)
    acc=accuracy_score(y_test,pred)
    print('accuracy score of at',r,'is',acc)
    if acc>max_score:
        max_score=acc
        random_state=r
        
print('\n')
print(max_score)
print(random_state)
# Out:
# accuracy score of at 42 is 1.0
# accuracy score of at 43 is 1.0
# accuracy score of at 44 is 1.0
# accuracy score of at 45 is 1.0
# accuracy score of at 46 is 1.0
# accuracy score of at 47 is 1.0
# accuracy score of at 48 is 1.0
# accuracy score of at 49 is 1.0
# accuracy score of at 50 is 1.0
# accuracy score of at 51 is 1.0
# accuracy score of at 52 is 1.0
# accuracy score of at 53 is 1.0
# accuracy score of at 54 is 1.0
# accuracy score of at 55 is 1.0
# accuracy score of at 56 is 1.0
# accuracy score of at 57 is 1.0
# accuracy score of at 58 is 1.0
# accuracy score of at 59 is 1.0
# accuracy score of at 60 is 1.0
# accuracy score of at 61 is 1.0
# accuracy score of at 62 is 1.0
# accuracy score of at 63 is 1.0
# accuracy score of at 64 is 1.0
# accuracy score of at 65 is 1.0
# accuracy score of at 66 is 1.0
# accuracy score of at 67 is 1.0
# accuracy score of at 68 is 1.0
# accuracy score of at 69 is 1.0
# accuracy score of at 70 is 1.0
# accuracy score of at 71 is 1.0
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=42)
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
pred=dtc.predict(x_test)

# %%
accuracy_score(y_test,pred)
# Out:
# 1.0

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[1257,    0],
#        [   0, 1181]], dtype=int64)

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
max_score=0

for r in range(40,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=r)
    mb=MultinomialNB()
    mb.fit(x_train,y_train)
    pred=mb.predict(x_test)
    acc=accuracy_score(y_test,pred)
    print("accuracy score at",r,"is",acc)
    
    if acc>max_score:
        max_score=acc
        random_stt=r
        
print(max_score)
print(random_stt)
# Out:
# accuracy score at 40 is 0.8068088597210828
# accuracy score at 41 is 0.7908121410992617
# accuracy score at 42 is 0.8027071369975389
# accuracy score at 43 is 0.7924528301886793
# accuracy score at 44 is 0.8063986874487284
# accuracy score at 45 is 0.8031173092698933
# accuracy score at 46 is 0.8092698933552092
# accuracy score at 47 is 0.7912223133716161
# accuracy score at 48 is 0.8084495488105005
# accuracy score at 49 is 0.8068088597210828
# accuracy score at 50 is 0.8068088597210828
# accuracy score at 51 is 0.8039376538146021
# accuracy score at 52 is 0.8010664479081214
# accuracy score at 53 is 0.8191140278917145
# accuracy score at 54 is 0.8170631665299426
# accuracy score at 55 is 0.8113207547169812
# accuracy score at 56 is 0.7965545529122231
# accuracy score at 57 is 0.8014766201804758
# accuracy score at 58 is 0.8047579983593109
# accuracy score at 59 is 0.8043478260869565
# accuracy score at 60 is 0.8010664479081214
# accuracy score at 61 is 0.8068088597210828
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=77)
mb.fit(x_train,y_train)
pred=mb.predict(x_test)

# %%
accuracy_score(y_test,pred)
# Out:
# 0.8207547169811321

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[1212,   88],
#        [ 349,  789]], dtype=int64)

# %% [markdown]
# # Crossvalidation

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(lg,x,y,cv=5).mean()
score
# Out:
# 0.8400878363016295

# %%
score=cross_val_score(kn,x,y,cv=5).mean()
score

# %%
score=cross_val_score(svc,x,y,cv=5).mean()
score

# %%
score=cross_val_score(dtc,x,y,cv=5).mean()
score

# %%
score=cross_val_score(mb,x,y,cv=5).mean()
score

# %% [markdown]
# as we can see the mean score of decisiontreeclassifier is higher so we select the decisiontreeclassifier for this dataset

# %% [markdown]
# # saving the model

# %%
from sklearn.externals import joblib

# %%
joblib.dump(dtc,'dtc_model_mushroom_dataset.obj')

# %%
joblib.load('dtc_model_mushroom_dataset.obj')
